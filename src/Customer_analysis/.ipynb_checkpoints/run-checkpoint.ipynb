# %%
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pathlib import Path
import polars.selectors as cs

# %%
input_folder=Path().resolve().parent /'input'
input_folder
# Out:
# PosixPath('/home/ahmed/MyOwnProjects/load-profile-decomposition/src/input')

# %%
pl.Config.set_tbl_cols(-1)
pl.Config.set_tbl_rows(-1)
# Out:
# polars.config.Config

# %% [markdown]
# Building customer demographics behaviour

# %%
pl.read_parquet(input_folder/'load_profile_buildingID_100284-28.parquet')

# %%
# %%time
dataset=pl.scan_parquet(input_folder/'load_profile_buildingID_*')
BUILDING_COUNTS=dataset.collect().select(pl.col('bldg_id')).unique().count().item()
dataset.collect()

# %% [markdown]
# ## First Hypothesis

# %%
Timining of the day significantly determines the consumption pattern

# %% [markdown]
# ## Second Hypothesis

# %% [markdown]
# net total energy consumption determines the peak load periods

# %% [markdown]
# ## Third Hypothesis

# %% [markdown]
# Simultaneous operation of two appliance creates a load on user's side
