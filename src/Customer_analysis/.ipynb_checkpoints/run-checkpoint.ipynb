# %%
import pandas as pd
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pathlib import Path
import polars.selectors as cs

# %%
input_folder=Path().resolve().parent /'input'
input_folder

# %%
pl.enable_string_cache()
pl.Config.set_streaming_chunk_size(2000000)
# Out:
# polars.config.Config

# %% [markdown]
# Building customer demographics behaviour

# %%
# %%time
dataset=pl.scan_parquet(input_folder/'load_profile_buildingID_*')
BUILDING_COUNTS=dataset.collect().select(pl.col('bldg_id')).unique().count().item()
dataset.collect()

# %% [markdown]
# ## The aim of this section is to find as many features as possible to build accurate hypothesis

# %%
Meta_data=pl.scan_parquet(input_folder/'Meta_Data.parquet').select(pl.col('in.occupants','in.state','in.county',
                        'in.representative_income','in.area_median_income','in.income',
                        'in.income_recs_2020','in.income_recs_2015', 'in.building_america_climate_zone',
                        'in.bedrooms','in.tenure','in.household_has_tribal_persons')
                ).unique().collect()
# Out:
# shape: (26_230, 12)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ in.occupa ┆ in.state ┆ in.county ┆ in.repres ┆ … ┆ in.buildi ┆ in.bedroo ┆ in.tenure ┆ in.househ │
# │ nts       ┆ ---      ┆ ---       ┆ entative_ ┆   ┆ ng_americ ┆ ms        ┆ ---       ┆ old_has_t │
# │ ---       ┆ str      ┆ str       ┆ income    ┆   ┆ a_climate ┆ ---       ┆ str       ┆ ribal_per │
# │ str       ┆          ┆           ┆ ---       ┆   ┆ _zo…      ┆ str       ┆           ┆ son…      │
# │           ┆          ┆           ┆ f32       ┆   ┆ ---       ┆           ┆           ┆ ---       │
# │           ┆          ┆           ┆           ┆   ┆ str       ┆           ┆           ┆ str       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2         ┆ FL       ┆ G1201050  ┆ 71582.0   ┆ … ┆ Hot-Humid ┆ 1         ┆ Owner     ┆ No        │
# │ 2         ┆ FL       ┆ G1200110  ┆ 50507.0   ┆ … ┆ Hot-Humid ┆ 3         ┆ Renter    ┆ No        │
# │ 1         ┆ FL       ┆ G1201150  ┆ 9508.0    ┆ … ┆ Hot-Humid ┆ 2         ┆ Renter    ┆ No        │
# │ 1         ┆ FL       ┆ G1200860  ┆ 10412.0   ┆ … ┆ Hot-Humid ┆ 1         ┆ Renter    ┆ No        │
# │ 4         ┆ FL       ┆ G1201050  ┆ 51862.0   ┆ … ┆ Hot-Humid ┆ 3         ┆ Renter    ┆ No        │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 4         ┆ FL       ┆ G1201170  ┆ 86332.0   ┆ … ┆ Hot-Humid ┆ 4         ┆ Renter    ┆ No        │
# │ 1         ┆ FL       ┆ G1201030  ┆ 17535.0   ┆ … ┆ Hot-Humid ┆ 2         ┆ Owner     ┆ No        │
# │ 7         ┆ FL       ┆ G1201030  ┆ 147645.0  ┆ … ┆ Hot-Humid ┆ 4         ┆ Owner     ┆ No        │
# │ 2         ┆ FL       ┆ G1200110  ┆ 55536.0   ┆ … ┆ Hot-Humid ┆ 3         ┆ Renter    ┆ No        │
# │ 1         ┆ FL       ┆ G1200210  ┆ 53672.0   ┆ … ┆ Hot-Humid ┆ 3         ┆ Owner     ┆ No        │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## First Hypothesis

# %% [markdown]
# the energy consumption patterns is significantly determined by the temporal attributes

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Objective 1: the hour of the day singificantly impact the consumption pattern

# %% [markdown]
# ### Objective 2: the day of the month singificantly impact the consumption pattern

# %% [markdown]
# ### Objective 3: the week of the month singificantly impact the consumption pattern

# %% [markdown]
# ### Objective 4: the month of the year singificantly impact the consumption pattern

# %% [markdown]
# ## Second Hypothesis

# %% [markdown]
# net total energy consumption determines the peak load periods

# %% [markdown]
# ## Third Hypothesis

# %% [markdown]
# Simultaneous operation of two appliance creates a load on user's side

# %% [markdown]
# ## Fourth Hypothesis

# %% [markdown]
# User Behaviour analysis
